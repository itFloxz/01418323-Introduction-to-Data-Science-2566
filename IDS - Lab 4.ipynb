# %% [markdown]
# #  Data Analysis Tools with Pandas 2 - SF Salaries Exercise
#
# แบบฝึกหัดนี้เป็นแบบฝึกหัดทดสอบทักษะการใช้งาน library pandas  ด้วย [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) จากเว็ปไซต์ Kaggle ให้ทำตามคำสั่ง ต่อไปนี้
#
# ---

# %% [markdown]
# **Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# **ให้นำเข้าข้อมูลจากไฟล์ Salaries.csv มาในรูปของ dataframe โดยตังชื่อตัวแปรว่า sal**

# %%
sal = pd.read_csv('Salaries.csv')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 3  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %% [markdown]
# **ใช้คำสั่ง .info() method to ในการดูภาพรวมของข้อมูลทั้งหมด**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **ลบคอลัมน์ Notes และ Status ออก**

# %%
sal.drop('Notes',axis=1,inplace = True)
sal.drop('Status',axis=1,inplace = True)

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       NaN  567595.43         567595.43  2011
# 1         245131.88  137811.38       NaN  538909.28         538909.28  2011
# 2         106088.18   16452.60       NaN  335279.91         335279.91  2011
# 3          56120.71  198306.90       NaN  332343.61         332343.61  2011
# 4           9737.00  182234.59       NaN  326373.19         326373.19  2011
# ...             ...        ...       ...        ...               ...   ...
# 148649         0.00       0.00       0.0       0.00              0.00  2014
# 148650          NaN        NaN       NaN       0.00              0.00  2014
# 148651          NaN        NaN       NaN       0.00              0.00  2014
# 148652          NaN        NaN       NaN       0.00              0.00  2014
# 148653         0.00    -618.13       0.0    -618.13           -618.13  2014
#
#                Agency
# 0       San Francisco
# 1       San Francisco
# 2       San Francisco
# 3       San Francisco
# 4       San Francisco
# ...               ...
# 148649  San Francisco
# 148650  San Francisco
# 148651  San Francisco
# 148652  San Francisco
# 148653  San Francisco
#
# [148654 rows x 11 columns]

# %% [markdown]
# **หาค่าเฉลี่ยนของ Benefits ใน sal**

# %%
sal["Benefits"].mean()
# Out:
# 25007.893150829852

# %% [markdown]
# **ใน sal แทน Benefits ที่เป็น null ด้วย 0**

# %%
sal['Benefits'].fillna(0 , inplace=True)

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# 1  2011  San Francisco
# 2  2011  San Francisco
# 3  2011  San Francisco
# 4  2011  San Francisco

# %% [markdown]
# **หาค่าเฉลี่ยนของ Benefits ใน sal อีกครั้ง**

# %%
sal["Benefits"].mean()
# Out:
# 18924.23283887417

# %% [markdown]
# **จงเพิ่มคอลัมน์ Year(TH) ใน sal ให้เป็นเลขปี พศ**

# %%
sal["Year(TH)"] = sal["Year"]+543

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       0.0  567595.43         567595.43  2011
# 1         245131.88  137811.38       0.0  538909.28         538909.28  2011
# 2         106088.18   16452.60       0.0  335279.91         335279.91  2011
# 3          56120.71  198306.90       0.0  332343.61         332343.61  2011
# 4           9737.00  182234.59       0.0  326373.19         326373.19  2011
# ...             ...        ...       ...        ...               ...   ...
# 148649         0.00       0.00       0.0       0.00              0.00  2014
# 148650          NaN        NaN       0.0       0.00              0.00  2014
# 148651          NaN        NaN       0.0       0.00              0.00  2014
# 148652          NaN        NaN       0.0       0.00              0.00  2014
# 148653         0.00    -618.13       0.0    -618.13           -618.13  2014
#
#                Agency  Year(TH)
# 0       San Francisco      2554
# 1       San Francisco      2554
# 2       San Francisco      2554
# 3       San Francisco      2554
# 4       San Francisco      2554
# ...               ...       ...
# 148649  San Francisco      2557
# 148650  San Francisco      2557
# 148651  San Francisco      2557
# 148652  San Francisco      2557
# 148653  San Francisco      2557
#
# [148654 rows x 12 columns]

# %% [markdown]
# **จงเพิ่มคอลัมน์ Level มีค่าเป็น L เมื่อ TotalPayBenefits น้อยกว่า 1 แสน และเป็น H เมื่อมากกว่าเท่ากับ 1 แสน**

# %%
sal["Level"] = sal["TotalPayBenefits"].apply(levels)

# %%
def levels(input):
    if(input < 100000 ) :
        return "L"
    else :
        return "H"

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# 148650                                    Not provided        NaN
# 148651                                    Not provided        NaN
# 148652                                    Not provided        NaN
# 148653                      Counselor, Log Cabin Ranch       0.00
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# 0              0.00  400184.25       0.0  567595.43         567595.43  2011
# 1         245131.88  137811.38       0.0  538909.28         538909.28  2011
# 2         106088.18   16452.60       0.0  335279.91         335279.91  2011
# 3          56120.71  198306.90       0.0  332343.61         332343.61  2011
# 4           9737.00  182234.59       0.0  326373.19         326373.19  2011
# ...             ...        ...       ...        ...               ...   ...
# 148649         0.00       0.00       0.0       0.00              0.00  2014
# 148650          NaN        NaN       0.0       0.00              0.00  2014
# 148651          NaN        NaN       0.0       0.00              0.00  2014
# 148652          NaN        NaN       0.0       0.00              0.00  2014
# 148653         0.00    -618.13       0.0    -618.13           -618.13  2014
#
#                Agency  Year(TH) Level
# 0       San Francisco      2554     H
# 1       San Francisco      2554     H
# 2       San Francisco      2554     H
# 3       San Francisco      2554     H
# 4       San Francisco      2554     H
# ...               ...       ...   ...
# 148649  San Francisco      2557     L
# 148650  San Francisco      2557     L
# 148651  San Francisco      2557     L
# 148652  San Francisco      2557     L
# 148653  San Francisco      2557     L
#
# [148654 rows x 13 columns]

# %% [markdown]
# **เซ็ต Id ให้เป็น index**

# %%
sal.set_index('Id',inplace = True)

# %%
sal
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# 1       167411.18         0.00  400184.25       0.0  567595.43
# 2       155966.02    245131.88  137811.38       0.0  538909.28
# 3       212739.13    106088.18   16452.60       0.0  335279.91
# 4        77916.00     56120.71  198306.90       0.0  332343.61
# 5       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148650       0.00         0.00       0.00       0.0       0.00
# 148651        NaN          NaN        NaN       0.0       0.00
# 148652        NaN          NaN        NaN       0.0       0.00
# 148653        NaN          NaN        NaN       0.0       0.00
# 148654       0.00         0.00    -618.13       0.0    -618.13
#
#         TotalPayBenefits  Year         Agency  Year(TH) Level
# Id
# 1              567595.43  2011  San Francisco      2554     H
# 2              538909.28  2011  San Francisco      2554     H
# 3              335279.91  2011  San Francisco      2554     H
# 4              332343.61  2011  San Francisco      2554     H
# 5              326373.19  2011  San Francisco      2554     H
# ...                  ...   ...            ...       ...   ...
# 148650              0.00  2014  San Francisco      2557     L
# 148651              0.00  2014  San Francisco      2557     L
# 148652              0.00  2014  San Francisco      2557     L
# 148653              0.00  2014  San Francisco      2557     L
# 148654           -618.13  2014  San Francisco      2557     L
#
# [148654 rows x 12 columns]

# %% [markdown]
# **เปลี่ยนชื่อคอลัมน์ Year เป็น Year(Eng)**

# %%
sal.rename(columns = {'Year':'Year(Eng)'},inplace = True)

# %%
sal
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148650      Roy I Tillery                                       Custodian
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# 1       167411.18         0.00  400184.25       0.0  567595.43
# 2       155966.02    245131.88  137811.38       0.0  538909.28
# 3       212739.13    106088.18   16452.60       0.0  335279.91
# 4        77916.00     56120.71  198306.90       0.0  332343.61
# 5       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148650       0.00         0.00       0.00       0.0       0.00
# 148651        NaN          NaN        NaN       0.0       0.00
# 148652        NaN          NaN        NaN       0.0       0.00
# 148653        NaN          NaN        NaN       0.0       0.00
# 148654       0.00         0.00    -618.13       0.0    -618.13
#
#         TotalPayBenefits  Year(Eng)         Agency  Year(TH) Level
# Id
# 1              567595.43       2011  San Francisco      2554     H
# 2              538909.28       2011  San Francisco      2554     H
# 3              335279.91       2011  San Francisco      2554     H
# 4              332343.61       2011  San Francisco      2554     H
# 5              326373.19       2011  San Francisco      2554     H
# ...                  ...        ...            ...       ...   ...
# 148650              0.00       2014  San Francisco      2557     L
# 148651              0.00       2014  San Francisco      2557     L
# 148652              0.00       2014  San Francisco      2557     L
# 148653              0.00       2014  San Francisco      2557     L
# 148654           -618.13       2014  San Francisco      2557     L
#
# [148654 rows x 12 columns]

# %% [markdown]
# **เพิ่มคนชื่อ David Copperfield ทำงานเป็น Magician คอลัม์อื่นๆเป็น null**

# %%
sal.loc[len(sal.index)+1,["EmployeeName","JobTitle"]] = ["David Copperfield","Magician"]

# %%
sal
# Out:
#              EmployeeName                                        JobTitle  \
# Id
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653       Not provided                                    Not provided
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
# 148655  David Copperfield                                        Magician
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# Id
# 1       167411.18         0.00  400184.25       0.0  567595.43
# 2       155966.02    245131.88  137811.38       0.0  538909.28
# 3       212739.13    106088.18   16452.60       0.0  335279.91
# 4        77916.00     56120.71  198306.90       0.0  332343.61
# 5       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148651        NaN          NaN        NaN       0.0       0.00
# 148652        NaN          NaN        NaN       0.0       0.00
# 148653        NaN          NaN        NaN       0.0       0.00
# 148654       0.00         0.00    -618.13       0.0    -618.13
# 148655        NaN          NaN        NaN       NaN        NaN
#
#         TotalPayBenefits  Year(Eng)         Agency  Year(TH) Level
# Id
# 1              567595.43     2011.0  San Francisco    2554.0     H
# 2              538909.28     2011.0  San Francisco    2554.0     H
# 3              335279.91     2011.0  San Francisco    2554.0     H
# 4              332343.61     2011.0  San Francisco    2554.0     H
# 5              326373.19     2011.0  San Francisco    2554.0     H
# ...                  ...        ...            ...       ...   ...
# 148651              0.00     2014.0  San Francisco    2557.0     L
# 148652              0.00     2014.0  San Francisco    2557.0     L
# 148653              0.00     2014.0  San Francisco    2557.0     L
# 148654           -618.13     2014.0  San Francisco    2557.0     L
# 148655               NaN        NaN            NaN       NaN   NaN
#
# [148655 rows x 12 columns]

# %% [markdown]
# **สร้าง Dataframe ที่ EmployeeName มีนาย A , B และ C ซึ่งมี BasePay เป็น 10000 แล้วนำไปรวมกับ sal**

# %%
data = [['A',10000],['B',10000],['C',10000]]
df = pd.DataFrame(data,columns=['EmployeeName','BasePay'])
df
# Out:
#   EmployeeName  BasePay
# 0            A    10000
# 1            B    10000
# 2            C    10000

# %%
sal = pd.concat([sal,df])
sal
# Out:
#              EmployeeName                                        JobTitle  \
# 1          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 3          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 5         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148654          Joe Lopez                      Counselor, Log Cabin Ranch
# 148655  David Copperfield                                        Magician
# 0                       A                                             NaN
# 1                       B                                             NaN
# 2                       C                                             NaN
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 1       167411.18         0.00  400184.25       0.0  567595.43
# 2       155966.02    245131.88  137811.38       0.0  538909.28
# 3       212739.13    106088.18   16452.60       0.0  335279.91
# 4        77916.00     56120.71  198306.90       0.0  332343.61
# 5       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148654       0.00         0.00    -618.13       0.0    -618.13
# 148655        NaN          NaN        NaN       NaN        NaN
# 0        10000.00          NaN        NaN       NaN        NaN
# 1        10000.00          NaN        NaN       NaN        NaN
# 2        10000.00          NaN        NaN       NaN        NaN
#
#         TotalPayBenefits  Year(Eng)         Agency  Year(TH) Level
# 1              567595.43     2011.0  San Francisco    2554.0     H
# 2              538909.28     2011.0  San Francisco    2554.0     H
# 3              335279.91     2011.0  San Francisco    2554.0     H
# 4              332343.61     2011.0  San Francisco    2554.0     H
# 5              326373.19     2011.0  San Francisco    2554.0     H
# ...                  ...        ...            ...       ...   ...
# 148654           -618.13     2014.0  San Francisco    2557.0     L
# 148655               NaN        NaN            NaN       NaN   NaN
# 0                    NaN        NaN            NaN       NaN   NaN
# 1                    NaN        NaN            NaN       NaN   NaN
# 2                    NaN        NaN            NaN       NaN   NaN
#
# [148658 rows x 12 columns]

# %% [markdown]
# **สร้างตาราง salB ซึ่งเก็บเฉพาะของคนที่ไม่มี BasePay**

# %%
salB = pd.DataFrame(sal[sal["BasePay"].isnull()])
salB.head()
# Out:
#             EmployeeName                   JobTitle  BasePay  OvertimePay  \
# 81392    Kevin P Cashman             Deputy Chief 3      NaN          0.0
# 84507  Demetrya  Mullens  Licensed Vocational Nurse      NaN          0.0
# 84961    Michael M Horan        Park Patrol Officer      NaN          0.0
# 90526       Thomas  Tang           Police Officer 3      NaN          0.0
# 90787     Michael C Hill             Deputy Sheriff      NaN          0.0
#
#         OtherPay  Benefits   TotalPay  TotalPayBenefits  Year(Eng)  \
# 81392  149934.11      0.00  149934.11         149934.11     2013.0
# 84507  110485.41  20779.00  110485.41         131264.41     2013.0
# 84961  120000.00   8841.48  120000.00         128841.48     2013.0
# 90526  106079.31      0.00  106079.31         106079.31     2013.0
# 90787   81299.02  23877.53   81299.02         105176.55     2013.0
#
#               Agency  Year(TH) Level
# 81392  San Francisco    2556.0     H
# 84507  San Francisco    2556.0     H
# 84961  San Francisco    2556.0     H
# 90526  San Francisco    2556.0     H
# 90787  San Francisco    2556.0     H

# %%
salB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610 entries, 81392 to 148655
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeName      610 non-null    object
#  1   JobTitle          610 non-null    object
#  2   BasePay           0 non-null      float64
#  3   OvertimePay       605 non-null    float64
#  4   OtherPay          605 non-null    float64
#  5   Benefits          609 non-null    float64
#  6   TotalPay          609 non-null    float64
#  7   TotalPayBenefits  609 non-null    float64
#  8   Year(Eng)         609 non-null    float64
#  9   Agency            609 non-null    object
#  10  Year(TH)          609 non-null    float64
#  11  Level             609 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 62.0+ KB

# %% [markdown]
# ### ----- ภาวนามยปัญญา ปัญญาที่เกิดจากการลงมือทำ! -----
